# %% [markdown]
# This notebook will be used to continue practicing data analysis with Xarray, Xmitgcm, Dask, etc. I
# want to use this notebook from 6.14-6.18 to continue manipulating netcdf data, creating at least
# one movie out of some of the data that we have, combining datasets using arithmetic operations to
# create new datasets, and efficiently parallelizing tasks.
#
# Specific Objectives:
# 1. Make a movie of U0's (first, open the netcdf file you created)
# 2. Pull V0 from Hector's files so you can compute surface ocean current speed.
# 3. Create a holoview movie of surface ocean current speeds
# 4. Shoot an email to Brian and Dimitris and Patrice

# %%
#accessing netcdf files from Hector's folders
import os, glob, sys
#playing with netcdf - xarray
import numpy as np
import xarray as xr
import dask.array as da
import dask_ndfilters

# %%
# this is where Hector has surface current data stored
datadir = '/nobackup/htorresg/air_sea/ocean-atmos/NCFILES/geosgcm_surf_tides_4km/'
# 
Udir = datadir + 'U_0/' 
Vdir = datadir + 'V_0/'
U_ncfiles = os.listdir(Udir)
V_ncfiles = os.listdir(Vdir)

# %% [markdown]
# Let me do what I did for U here, just for V (so these should be the longitudinal velocities).

# %%
V_dir_files = [] #holds the full names of the files with the directory prefix

for i in range(0,len(V_ncfiles)):
    V_dir_files.append(Vdir+V_ncfiles[i])
V_full_set = xr.open_mfdataset(V_dir_files, chunks={'latitude': 10, 'longitude': 10}, concat_dim='time',parallel=True, combine='nested')
#try this with a dask diagnostics check

# %%
#with any luck the previous step actually worked correctly
#now, I'll save it to my folder in /nobackup
personal_dir = '/nobackup/amondal/NCData/FirstAttempt/'
filename ='V0_full.nc'
#V_full_set
#V_full_set.to_netcdf(path=(personal_dir + filename))

# %% [markdown]
# I repeatedly got server errors after the last code - it may be good to prepare separate python scripts that can also run in the terminal without the front end. Let's check if V got saved.

# %%
U0_full_name = personal_dir + 'U0_full.nc'
V0_full_name = personal_dir + filename
U0_full = xr.open_dataset(U0_full_name)
U0_full
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4501, lon: 9000, time: 2672)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.96 -89.92 -89.88 ... 89.88 89.92 89.96 90.0
#   * lon      (lon) float64 -180.0 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Dimensions without coordinates: time
# Data variables:
#     U        (time, lat, lon) float64 ...

# %%
V0_full = xr.open_dataset(V0_full_name)
V0_full
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4501, lon: 9000, time: 2689)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.96 -89.92 -89.88 ... 89.88 89.92 89.96 90.0
#   * lon      (lon) float64 -180.0 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Dimensions without coordinates: time
# Data variables:
#     V        (time, lat, lon) float64 ...

# %% [markdown]
# Super weird that these two are different sizes. Maybe something got screwed up when you saved the U0 as
# a dataset last week. For now, I'll just shorten it to match.

# %%
print(V0_full.sizes)
# Out:
# Frozen(SortedKeysDict({'lat': 4501, 'lon': 9000, 'time': 2689}))

# %%
print(V0_full.dims['time'])
# Out:
# 2689

# %%
print(U0_full.dims['time'])
# Out:
# 2672

# %%
V0_full_match = V0_full.isel(time=slice(0,U0_full.dims['time']))

# %%
V0_full_match
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 4501, lon: 9000, time: 2672)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.96 -89.92 -89.88 ... 89.88 89.92 89.96 90.0
#   * lon      (lon) float64 -180.0 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Dimensions without coordinates: time
# Data variables:
#     V        (time, lat, lon) float64 ...

# %% [markdown]
# Now I want to combine these two to get surface current speeds.

# %%
SSpeed_full = xr.ufunc.sqrt(xr.ufunc.square(U0_full) + xr.ufunc.square(V0_full_match))
