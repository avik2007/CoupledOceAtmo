# %%
#accessing netcdf files from Hector's folders
import os, glob, sys
sys.path.append("//nobackup//amondal//Python//Hector_Python_Scripts")
sys.path.append("//nobackup/amondal//Python//mit_geos_analysis")
#playing with netcdf - xarray
import numpy as np
import xarray as xr
import dask.array as da
import matplotlib.pyplot as plt
import dask_ndfilters
# How about visualization?
# %matplotlib inline
import xrscipy.signal as dsp
import xrft
import scipy.signal as scp
import netCDF4
import xgcm
from netCDF4 import Dataset
import time as tm
from xmitgcm import open_mdsdataset
import time as tm
import pylab as plt
from llcmap_bi_split import LLCMap_bi_split
from face_connections import face_connections
from llcmap_nea_split import LLCMap_nea_split
from timeline_MITgcm import timeline
from datetime import datetime, timedelta
import importlib
from GetNCDataSet import getMITNCDataSet
from MIT_xr_cwt_dateloc_fol import loadMITData
from MITllc2160Depth import *



from dask.distributed import Client
client = Client(memory_limit='90GB',n_workers = 40, threads_per_worker=1)
# Out:
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-x34penvo', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-e352q0ic', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-ewopkez3', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-xvg98luk', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-74pce8_1', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-2glluwpl', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-y90jdvx9', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-znge06cg', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-p2t3bd_y', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-660wgkgo', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-jzjrl0o7', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-xvbyirkf', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-kqr6k1qx', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-zfimu1qf', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-pn1thkd4', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-ult3odb_', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-4nw_c6vl', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-ajolnclg', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-an52342d', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-zgjl4tj9', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-_9bqgm0_', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-nt9xbnfg', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-b4hyxokp', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-3rk8mded', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-9h3koizc', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-ukrxf4ne', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-xz_kg13l', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-3k73bl3b', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-gzxat989', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-tbywu_7t', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-qlixc0zg', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-c0h90l_r', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-8blrhxxd', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-mwi36d31', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-eqdthjxn', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-f08q1b72', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-jn0cka7y', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-4ooy3vwj', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-yhslui0h', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/nobackupp12/amondal/Python/mit_geos_analysis/dask-worker-space/worker-w793o7hx', purging
# /nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/contextlib.py:142: UserWarning: Creating scratch directories is taking a surprisingly long time. This is often due to running workers on a network file system. Consider specifying a local-directory to point workers to write scratch data to a local disk.
#   next(self.gen)

# %% [markdown]
# Coordinates for this section:
#
# 30N - 42N
# 40W - 65W
# Mar 1 - Jun 1

# %%
zlayerToDepth(31)
# Out:
# 274.98499999999996

# %%
hbl = getMITNCDataSet('/nobackup/amondal/NCData/20211116_QTprime_openocean_3month/', 'KPPhbl', 0,0 )
# Out:
# Time combined dataset has been opened.
# I concatenated the first Z-layer

# %%
hblc = hbl.KPPhbl.compute()
# Out:
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_generic_released;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2046'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'

# %%
hblcm = hblc.mean(dim=['lat','lon'])

# %%
# %matplotlib inline
hblcm.plot()

# %%
hblcv = hblc.var(dim=['lat','lon'])

# %%
# %matplotlib inline
hblcv.plot()

# %%
T = getMITNCDataSet('/nobackup/amondal/NCData/20211116_QTprime_openocean_3month/', 'Theta', 30, 31)
W = getMITNCDataSet('/nobackup/amondal/NCData/20211116_QTprime_openocean_3month/', 'W', 30, 31)
#hbl = getMITNCDataSet('/nobackup/amondal/NCData/20211116_QTprime_openocean_3month/', 'KPPhbl', 0,0 )
# Out:
# Time combined dataset has been opened.
# I concatenated the first Z-layer
# Time combined dataset has been opened
# I concatenated another Z-layer
# Time combined dataset has been opened.
# I concatenated the first Z-layer
# Time combined dataset has been opened
# I concatenated another Z-layer
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: '_propagate_forgotten;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/scheduler.py;7945'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'

# %%
hblc = hbl.KPPhbl.compute()

# %%
Tc = T.compute()
Wc = W.compute()
# Out:
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_generic_released;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2046'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_released_forgotten;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2436'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#     d = state["children"][ident]
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
# KeyError: 'transition_generic_released;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2046'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_released_forgotten;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2436'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'

# %% [markdown]
# Important note - xrft does not handle nans. So you cannot analyze NANS in your analysis.

# %% [markdown]
# So how do we detrend? Probably just use detrend_type constant in space right?

# %%
Tp = xrft.detrend(Tc.Theta, dim='lat', detrend_type = 'constant')
Wp = xrft.detrend(Wc.W, dim='lat', detrend_type = 'constant')
Tprime = xrft.detrend(Tp, dim='lon',detrend_type='constant')
Wprime = xrft.detrend(Wp,dim='lon', detrend_type='constant')

# %%
Q= Wprime*Tprime

#this is a spectra of Q - you want a cospectra!!! RECALCULATE!!

# %%
Q
# Out:
# <xarray.DataArray (Zlayers: 2, time: 2208, lat: 300, lon: 625)>
# array([[[[ 7.70948845e-03,  6.06898132e-03,  5.59438453e-03, ...,
#           -4.32244715e-06, -4.42988823e-04, -5.32230491e-04],
#          [ 6.75825403e-03,  5.62212308e-03,  5.62337221e-03, ...,
#           -5.23556717e-04, -4.85004470e-04, -2.15062520e-04],
#          [ 3.46161119e-03,  3.71257689e-03,  4.06777578e-03, ...,
#           -2.76570170e-04, -8.55997907e-05,  2.00949774e-04],
#          ...,
#          [ 3.17410835e-02,  3.18574081e-02,  2.50535512e-02, ...,
#            1.53388007e-04,  4.50666668e-05, -1.58891885e-04],
#          [ 1.40365973e-02,  2.46078088e-02,  2.81748071e-02, ...,
#            1.15993982e-04,  1.04001239e-04, -6.97531175e-05],
#          [ 8.31455012e-03,  2.10136448e-02,  2.82697088e-02, ...,
#            5.69905111e-05,  1.75014121e-04,  3.33806321e-05]],
#
#         [[ 6.40607880e-03,  5.27954177e-03,  6.50408892e-03, ...,
#            2.92403567e-04, -1.10001712e-05,  6.67124364e-05],
#          [ 4.08863630e-03,  4.26670365e-03,  6.09788944e-03, ...,
#            1.42170329e-04,  2.67374589e-04,  6.94770442e-04],
#          [ 2.86432608e-04,  1.30197047e-03,  3.26935312e-03, ...,
#           -3.83431349e-04, -3.19184412e-05,  3.32086072e-04],
# ...
#          [-1.23358321e-02, -1.45383838e-02, -2.09065122e-02, ...,
#            8.97855269e-04,  1.01990922e-03,  6.65583966e-04],
#          [-1.65855726e-02, -1.56385604e-02, -1.75858834e-02, ...,
#            9.35237296e-04,  9.50929861e-04,  7.79224018e-04],
#          [-9.09767331e-03, -7.76802294e-03, -1.13961706e-02, ...,
#            7.16117442e-04,  7.32646704e-04,  7.16029406e-04]],
#
#         [[-1.15181756e-04, -1.95743288e-04, -2.41316656e-04, ...,
#           -2.00856746e-04, -2.77945232e-04, -1.42514688e-04],
#          [ 1.78991179e-03,  1.16060678e-03,  9.09829114e-04, ...,
#            5.65700830e-05, -1.62344923e-04, -2.73900061e-04],
#          [ 1.98731359e-03,  9.82814614e-04,  6.80687313e-04, ...,
#           -5.41217295e-04, -8.37845782e-04, -9.97822406e-04],
#          ...,
#          [-1.28865974e-02, -7.23450597e-03, -9.38744251e-03, ...,
#            6.92679317e-04,  1.19743435e-03,  7.95085022e-04],
#          [-7.53777973e-03, -3.19052090e-03, -2.37773474e-03, ...,
#            3.15723384e-04,  8.63070463e-04,  8.38243643e-04],
#          [-8.83288874e-03, -1.92710195e-03,  2.76812153e-03, ...,
#            3.92008112e-05,  4.37426054e-04,  6.07914439e-04]]]])
# Coordinates:
#   * lat      (lat) float64 30.0 30.04 30.08 30.12 ... 41.84 41.88 41.92 41.96
#   * lon      (lon) float64 -65.0 -64.96 -64.92 -64.88 ... -40.12 -40.08 -40.04
# Dimensions without coordinates: Zlayers, time

# %%
Qt = xrft.xrft.fft(Q, dim='time', real_dim='time', detrend = 'linear', window='tukey', true_amplitude='True')

# %%
Qtxy = xrft.xrft.fft(Qt, dim=['lat','lon'],detrend='linear', window='tukey')

# %%
Qtxy
# Out:
# <xarray.DataArray (Zlayers: 2, freq_time: 1105, freq_lat: 300, freq_lon: 625)>
# array([[[[ 3.39880332e-01+4.36604553e-01j,
#            4.41037958e-01-1.22182284e+00j,
#           -4.21657261e-01+2.56100706e-01j, ...,
#           -4.21657261e-01-2.56100706e-01j,
#            4.41037958e-01+1.22182284e+00j,
#            3.39880332e-01-4.36604553e-01j],
#          [-4.95136362e-01+6.31936148e-01j,
#            1.80015581e-01+2.19190387e-01j,
#           -8.13061343e-02+5.57529525e-01j, ...,
#            7.99300434e-01+1.17463415e-01j,
#           -1.28514919e+00-3.25208181e-01j,
#           -2.00824704e-02-6.41893999e-01j],
#          [-3.67087382e-01-7.12124060e-01j,
#            5.55442841e-01-7.40983449e-02j,
#            3.01227955e-01-5.61712148e-01j, ...,
#           -2.86953728e-01+7.10574318e-01j,
#            1.51661566e-01+3.23337791e-02j,
#            7.71874575e-01+1.32606346e+00j],
#          ...,
#          [-2.25835546e-01-8.36584214e-01j,
# ...
#           -1.61947854e-01+2.15621500e-01j],
#          ...,
#          [ 4.24630429e-01+7.88849339e-02j,
#           -3.15184362e-01-1.06110910e-01j,
#           -2.15234527e-01+7.31952765e-02j, ...,
#            9.19377140e-02+3.49053472e-02j,
#            1.14052430e-01+2.42394261e-01j,
#           -1.10323080e-01-8.11357237e-02j],
#          [-1.61947854e-01-2.15621500e-01j,
#            1.50123187e-01+1.83671750e-01j,
#            1.39783212e-01+7.83175774e-02j, ...,
#            1.19285114e-01+2.99508247e-01j,
#            2.09323835e-01-2.33301060e-01j,
#           -1.31368760e-02+5.04859769e-02j],
#          [-8.63087963e-02+3.25811738e-01j,
#            2.71320623e-01-4.53177599e-02j,
#            2.46274149e-01-2.94254713e-01j, ...,
#           -2.21362158e-02-7.38099159e-02j,
#           -1.11639269e-01-2.66189361e-02j,
#           -7.61211371e-02-1.04554837e-01j]]]])
# Coordinates:
#   * freq_time  (freq_time) float64 0.0 0.0004529 0.0009058 ... 0.4991 0.4995 0.5
#   * freq_lat   (freq_lat) float64 -12.5 -12.42 -12.33 ... 12.25 12.33 12.42
#   * freq_lon   (freq_lon) float64 -12.48 -12.44 -12.4 ... 12.4 12.44 12.48
# Dimensions without coordinates: Zlayers

# %%
Qtxy.rename("Layer 26,27 Freq Wlength Plot")
Qtxy.to_netcdf('/nobackup/amondal/NCData/20211130_FreqWvnb_WT_plots/Qtx26_27.nc4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-8921006461c9> in <module>
#       1 Qtxy.rename("Layer 26,27 Freq Wlength Plot")
# ----> 2 Qtxy.to_netcdf('/nobackup/amondal/NCData/20211130_FreqWvnb_WT_plots/Qtx26_27.nc4')
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/core/dataarray.py in to_netcdf(self, *args, **kwargs)
#    2758             dataset = self.to_dataset()
#    2759
# -> 2760         return dataset.to_netcdf(*args, **kwargs)
#    2761
#    2762     def to_dict(self, data: bool = True) -> dict:
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1782         from ..backends.api import to_netcdf
#    1783
# -> 1784         return to_netcdf(
#    1785             self,
#    1786             path,
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1081         # TODO: allow this work (setting up the file for writing array data)
#    1082         # to be parallelized with dask
# -> 1083         dump_to_store(
#    1084             dataset, store, writer, encoding=encoding, unlimited_dims=unlimited_dims
#    1085         )
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/backends/api.py in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1128         variables, attrs = encoder(variables, attrs)
#    1129
# -> 1130     store.store(variables, attrs, check_encoding, writer, unlimited_dims=unlimited_dims)
#    1131
#    1132
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/backends/common.py in store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     265         self.set_attributes(attributes)
#     266         self.set_dimensions(variables, unlimited_dims=unlimited_dims)
# --> 267         self.set_variables(
#     268             variables, check_encoding_set, writer, unlimited_dims=unlimited_dims
#     269         )
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/backends/common.py in set_variables(self, variables, check_encoding_set, writer, unlimited_dims)
#     303             name = _encode_variable_name(vn)
#     304             check = vn in check_encoding_set
# --> 305             target, source = self.prepare_variable(
#     306                 name, v, check, unlimited_dims=unlimited_dims
#     307             )
#
# ~/.conda/envs/xmitgcm3/lib/python3.8/site-packages/xarray/backends/netCDF4_.py in prepare_variable(self, name, variable, check_encoding, unlimited_dims)
#     486             nc4_var = self.ds.variables[name]
#     487         else:
# --> 488             nc4_var = self.ds.createVariable(
#     489                 varname=name,
#     490                 datatype=datatype,
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.createVariable()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__init__()
#
# TypeError: illegal primitive data type, must be one of dict_keys(['S1', 'i1', 'u1', 'i2', 'u2', 'i4', 'u4', 'i8', 'u8', 'f4', 'f8']), got complex128

# %%
Qtiso26.rename("Layer 26 Freq/Wlngth Plot")
# Out:
# <xarray.DataArray 'Layer 26 Freq/Wlngth Plot' (freq_time: 1105, kr: 135)>
# array([[ 1.6249167 , -3.19329119,  4.30661315, ...,  0.32977928,
#          1.28966248, -2.33050776],
#        [-0.37147289,  1.15937188, -4.96961429, ...,  0.25238692,
#         -0.41359682,  2.25957866],
#        [-1.51690863,  2.72600525,  0.96061868, ...,  0.2222811 ,
#         -2.85213065,  1.65894578],
#        ...,
#        [ 0.02770334, -0.01742694, -0.04823711, ...,  0.28314583,
#         -0.46616778,  0.37873729],
#        [-0.02237081,  0.02124853,  0.11154337, ..., -0.39303467,
#          0.29763011, -0.07125316],
#        [-0.00840423, -0.03534896,  0.04487297, ...,  0.06332645,
#          0.47703343, -0.7336367 ]])
# Coordinates:
#   * freq_time  (freq_time) float64 0.0 0.0004529 0.0009058 ... 0.4991 0.4995 0.5
#   * kr         (kr) float64 0.04622 0.1387 0.2311 0.3235 ... 12.25 12.34 12.43

# %%
from spectral_analysis_code import *
Qtiso26 = isotropize(Qtxy.isel(Zlayers=0), ['freq_lat','freq_lon'], 'freq_time')
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# Task exception was never retrieved
# future: <Task finished name='Task-71589' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Task exception was never retrieved
# future: <Task finished name='Task-71586' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Task exception was never retrieved
# future: <Task finished name='Task-71588' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Task exception was never retrieved
# future: <Task finished name='Task-71587' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Task exception was never retrieved
# future: <Task finished name='Task-71585' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# Task exception was never retrieved
# future: <Task finished name='Task-71584' coro=<PooledRPCCall.__getattr__.<locals>.send_recv_from_rpc() done, defined at /home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py:856> exception=CommClosedError('in <closed TCP>: Stream is closed')>
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 196, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 864, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/core.py", line 647, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 206, in read
#     convert_stream_closed_error(self, e)
#   File "/home6/amondal/.conda/envs/xmitgcm3/lib/python3.8/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError("in %s: %s" % (obj, exc)) from exc
# distributed.comm.core.CommClosedError: in <closed TCP>: Stream is closed
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing

# %%
Qtiso27 = isotropize(Qtxy.isel(Zlayers=1), ['freq_lat','freq_lon'], 'freq_time')

# %%
# %matplotlib inline
Qtiso26.plot()

# %%
Qtiso27.plot()

# %%
from spectral_analysis_code import *
Qtiso28 = isotropize(Qtxy.isel(Zlayers=0), ['freq_lat','freq_lon'], 'freq_time')

# %%
# %matplotlib inline
Qtiso28.plot()

# %%
from spectral_analysis_code import *
Qtiso29 = isotropize(Qtxy.isel(Zlayers=1), ['freq_lat','freq_lon'], 'freq_time')

# %%
# %matplotlib inline
Qtiso29.plot()

# %%
from spectral_analysis_code import *
Qtiso30 = isotropize(Qtxy.isel(Zlayers=0), ['freq_lat','freq_lon'], 'freq_time')
Qtiso31 = isotropize(Qtxy.isel(Zlayers=1), ['freq_lat', 'freq_lon'], 'freq_time')

# %%
abQ30 = np.abs(Qtiso30)
abQ31 = np.abs(Qtiso31)

# %%
abQ30
# Out:
# <xarray.DataArray 'Isotropic Spectra' (freq_time: 1105, kr: 135)>
# array([[0.54904944, 1.56474949, 3.62068782, ..., 0.51498579, 1.51805131,
#         1.29688716],
#        [0.65661239, 0.40249432, 5.54605571, ..., 0.37711862, 0.95492709,
#         1.68633987],
#        [1.9571585 , 3.07777246, 3.6390868 , ..., 0.64161754, 1.22019805,
#         0.06969505],
#        ...,
#        [0.02224529, 0.0912642 , 0.07047828, ..., 0.85069792, 1.04328099,
#         0.89936388],
#        [0.00753302, 0.05247033, 0.29282954, ..., 0.22838828, 0.11773502,
#         0.37986838],
#        [0.02617432, 0.0804829 , 0.10660693, ..., 0.79383947, 1.37880298,
#         0.85296173]])
# Coordinates:
#   * freq_time  (freq_time) float64 0.0 0.0004529 0.0009058 ... 0.4991 0.4995 0.5
#   * kr         (kr) float64 0.04622 0.1387 0.2311 0.3235 ... 12.25 12.34 12.43

# %%
# %matplotlib inline
abQ30[1:-1].plot(xscale='log',yscale='log')

# %%
# %matplotlib inline
labQ30 = np.log(abQ30)
labQ30
# Out:
# <xarray.DataArray 'Isotropic Spectra' (freq_time: 1105, kr: 135)>
# array([[-0.59956679,  0.44772574,  1.28666401, ..., -0.66361597,
#          0.41742748,  0.2599669 ],
#        [-0.42066141, -0.91007429,  1.71308699, ..., -0.97519551,
#         -0.04612028,  0.52256042],
#        [ 0.67149367,  1.12420611,  1.29173277, ..., -0.44376289,
#          0.19901318, -2.66362592],
#        ...,
#        [-3.80562511, -2.39399667, -2.65245067, ..., -0.16169818,
#          0.04237054, -0.10606756],
#        [-4.88845862, -2.94750734, -1.22816462, ..., -1.4767081 ,
#         -2.13931873, -0.96793047],
#        [-3.64297636, -2.51971048, -2.23860678, ..., -0.23087402,
#          0.32121572, -0.1590406 ]])
# Coordinates:
#   * freq_time  (freq_time) float64 0.0 0.0004529 0.0009058 ... 0.4991 0.4995 0.5
#   * kr         (kr) float64 0.04622 0.1387 0.2311 0.3235 ... 12.25 12.34 12.43

# %%
# %matplotlib inline
labQ30[1:-1].plot(xscale='log',yscale='log')

# %%
# this is a stand in until you figure out Joe's Symlog stuff
def symlog(xa):
    xapos = xr.where(xa > 1, xa, 1)
    xaneg = xr.where(xa < -1, xa, -1)
    lxapos = xr.apply_ufunc(np.log, xapos)
    lxaneg = xr.apply_ufunc(np.log, -1*xaneg)
    symxa = lxapos - lxaneg
    return symxa

# %%
sQtiso26 = symlog(Qtiso26)
sQtiso27 = symlog(Qtiso27)

# %% [markdown]
# So 12/6 suggestion is to try to understand what's going on with with just 1d spectra. So we'll start with time and then work our way to space and then both.

# %%
Q.time
# Out:
# <xarray.DataArray 'time' (time: 2208)>
# array([   0,    1,    2, ..., 2205, 2206, 2207])
# Dimensions without coordinates: time

# %%
Q.assign_coords({"time": Q.time})
# Out:
# <xarray.DataArray (Zlayers: 2, time: 2208, lat: 300, lon: 625)>
# array([[[[ 7.70948845e-03,  6.06898132e-03,  5.59438453e-03, ...,
#           -4.32244715e-06, -4.42988823e-04, -5.32230491e-04],
#          [ 6.75825403e-03,  5.62212308e-03,  5.62337221e-03, ...,
#           -5.23556717e-04, -4.85004470e-04, -2.15062520e-04],
#          [ 3.46161119e-03,  3.71257689e-03,  4.06777578e-03, ...,
#           -2.76570170e-04, -8.55997907e-05,  2.00949774e-04],
#          ...,
#          [ 3.17410835e-02,  3.18574081e-02,  2.50535512e-02, ...,
#            1.53388007e-04,  4.50666668e-05, -1.58891885e-04],
#          [ 1.40365973e-02,  2.46078088e-02,  2.81748071e-02, ...,
#            1.15993982e-04,  1.04001239e-04, -6.97531175e-05],
#          [ 8.31455012e-03,  2.10136448e-02,  2.82697088e-02, ...,
#            5.69905111e-05,  1.75014121e-04,  3.33806321e-05]],
#
#         [[ 6.40607880e-03,  5.27954177e-03,  6.50408892e-03, ...,
#            2.92403567e-04, -1.10001712e-05,  6.67124364e-05],
#          [ 4.08863630e-03,  4.26670365e-03,  6.09788944e-03, ...,
#            1.42170329e-04,  2.67374589e-04,  6.94770442e-04],
#          [ 2.86432608e-04,  1.30197047e-03,  3.26935312e-03, ...,
#           -3.83431349e-04, -3.19184412e-05,  3.32086072e-04],
# ...
#          [-1.23358321e-02, -1.45383838e-02, -2.09065122e-02, ...,
#            8.97855269e-04,  1.01990922e-03,  6.65583966e-04],
#          [-1.65855726e-02, -1.56385604e-02, -1.75858834e-02, ...,
#            9.35237296e-04,  9.50929861e-04,  7.79224018e-04],
#          [-9.09767331e-03, -7.76802294e-03, -1.13961706e-02, ...,
#            7.16117442e-04,  7.32646704e-04,  7.16029406e-04]],
#
#         [[-1.15181756e-04, -1.95743288e-04, -2.41316656e-04, ...,
#           -2.00856746e-04, -2.77945232e-04, -1.42514688e-04],
#          [ 1.78991179e-03,  1.16060678e-03,  9.09829114e-04, ...,
#            5.65700830e-05, -1.62344923e-04, -2.73900061e-04],
#          [ 1.98731359e-03,  9.82814614e-04,  6.80687313e-04, ...,
#           -5.41217295e-04, -8.37845782e-04, -9.97822406e-04],
#          ...,
#          [-1.28865974e-02, -7.23450597e-03, -9.38744251e-03, ...,
#            6.92679317e-04,  1.19743435e-03,  7.95085022e-04],
#          [-7.53777973e-03, -3.19052090e-03, -2.37773474e-03, ...,
#            3.15723384e-04,  8.63070463e-04,  8.38243643e-04],
#          [-8.83288874e-03, -1.92710195e-03,  2.76812153e-03, ...,
#            3.92008112e-05,  4.37426054e-04,  6.07914439e-04]]]])
# Coordinates:
#   * lat      (lat) float64 30.0 30.04 30.08 30.12 ... 41.84 41.88 41.92 41.96
#   * lon      (lon) float64 -65.0 -64.96 -64.92 -64.88 ... -40.12 -40.08 -40.04
#   * time     (time) int64 0 1 2 3 4 5 6 7 ... 2201 2202 2203 2204 2205 2206 2207
# Dimensions without coordinates: Zlayers

# %%
Qt = xrft.xrft.fft(Q, dim='time', real_dim='time', detrend = 'linear', window='tukey', true_amplitude='True')

# %%
Qt3031 = Qt#Qt for layers 30 and 31
Qt3031_omega = Qt3031.mean(dim=['lat','lon'])

# %%
Qt_omega = np.abs(Qt3031_omega)

# %%
Qt_omega.sel(Zlayers=0).plot(xscale='log', yscale = 'log')

# %%
#No idea if this is reasonable ^^, but there are definitely weird peaks. There is more action happening on the right scales so that much makes sense.

# %%
T = getMITNCDataSet('/nobackup/amondal/NCData/20211103_multicoretest_3month/', 'Theta', 1, 5)
Tc = T.compute()
# Out:
# Time combined dataset has been opened.
# I concatenated the first Z-layer
# Time combined dataset has been opened
# I concatenated another Z-layer
# Time combined dataset has been opened
# I concatenated another Z-layer
# Time combined dataset has been opened
# I concatenated another Z-layer
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_released_forgotten;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2436'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'
# Time combined dataset has been opened
# I concatenated another Z-layer
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
# Exception in thread Profile:
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 115, in process
#     d = state["children"][ident]
# KeyError: 'transition_generic_released;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2046'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'
#     d = state["children"][ident]
# KeyError: 'transition_generic_released;/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/worker.py;2046'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 274, in _watch
#     process(frame, None, recent, omit=omit)
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 119, in process
#     "description": info_frame(frame),
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/site-packages/distributed/profile.py", line 72, in info_frame
#     line = linecache.getline(co.co_filename, frame.f_lineno, frame.f_globals).lstrip()
#   File "/nobackup/amondal/.conda/envs/xmitgcm4/lib/python3.10/linecache.py", line 31, in getline
#     if 1 <= lineno <= len(lines):
# TypeError: '<=' not supported between instances of 'int' and 'NoneType'

# %%
Tc = Tc.sel(lat=slice(35, 45))
Tp = xrft.detrend(Tc.Theta, dim='lat', detrend_type = 'linear')

# %%
Tpomega = xrft.xrft.fft(Tp, dim='time', real_dim='time', detrend = 'linear', window='tukey', true_amplitude='True')

# %%
Tpomega_bar = Tpomega.mean(dim=['lat','lon', 'Zlayers'])

# %%
Tpomega_bar_abs = np.abs(Tpomega_bar)

# %%
Tpomega_bar_abs.plot(xscale = 'log', yscale = 'log')

# %%
Tc.Theta.isel(Zlayers=0, time=0)
# Out:
# <xarray.DataArray 'Theta' (lat: 375, lon: 375)>
# array([[18.52941513, 18.52941513, 18.52387619, ..., 17.17543221,
#         17.28687096, 17.36539841],
#        [18.52375793, 18.52375793, 18.49901772, ..., 17.17926025,
#         17.38815689, 17.47924805],
#        [18.47663498, 18.47663498, 18.43268776, ..., 17.2299118 ,
#         17.50032806, 17.6009655 ],
#        ...,
#        [ 0.13681561,  0.13681561, -0.10579435, ...,  5.36168385,
#          6.02215958,  6.60452318],
#        [-0.14354479, -0.14354479, -0.03696107, ...,  5.30365038,
#          5.57920742,  5.94111252],
#        [ 0.05489781,  0.05489781,  0.22084467, ...,  5.15139866,
#          5.24470901,  5.37615442]])
# Coordinates:
#   * lat      (lat) float64 35.0 35.04 35.08 35.12 ... 49.84 49.88 49.92 49.96
#   * lon      (lon) float64 -60.0 -59.96 -59.92 -59.88 ... -45.12 -45.08 -45.04

# %%
Q = getMITNCDataSet('/nobackup/amondal/NCData/20210830_RegBal_5day/', 'oceQnet', 0, 0)
Qc = Q.compute()
# Out:
# Time combined dataset has been opened.
# I concatenated the first Z-layer

# %%
Qc
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 25, time: 120)
# Coordinates:
#   * lat      (lat) float64 34.0 34.04 34.08 34.12 ... 34.84 34.88 34.92 34.96
#   * lon      (lon) float64 -65.0 -64.96 -64.92 -64.88 ... -64.12 -64.08 -64.04
# Dimensions without coordinates: time
# Data variables:
#     oceQnet  (time, lat, lon) float64 324.9 373.6 352.0 ... 200.3 140.8 173.3

# %%
Qf = xrft.xrft.fft(Qc.oceQnet, dim='time', real_dim='time', detrend = 'linear', window='tukey', true_amplitude='True')

# %%
Qfs = Qf.sum(dim=['lat','lon'])

# %%
Qfsa = np.abs(Qfs)

# %%
Qfsa.plot(xscale='log')

# %%
k0 = 1/0.52
T = 4.
dx = 0.02
x = np.arange(-2*T,2*T,dx)
y = np.cos(2*np.pi*k0*x)
#y[np.abs(x)>T/2]=0.
da = xr.DataArray(y, dims=('x',), coords={'x':x})

# %%
fig, ax = plt.subplots(figsize=(12,4))
fig.set_tight_layout(True)
da.plot(ax=ax, marker='+', label='original signal')
ax.set_xlim([-8,8]);

# %%
da_fft = xrft.fft(da,window='tukey') 
da_fft_abs = np.abs(da_fft)

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(4,4))
da_fft_abs.plot()
fig.set_tight_layout(True)
ax.set_xlim([-3,3]);

# %% [markdown]
#
#
# Inputs:
#
# k,l := horizontal components of the wavenumber vector k with size N and l with size M
#
# E := spectrum with size N x M.
#
#
# Outputs:
# Kr := radial wavenumber
# Ispec := isotropic spectrum

# %%
#:::::::::::::::::::::::::::::::::::::::::::::::
import math
def calc_ispec(k,l,E):
    """ calculates isotropic spectrum from 2D spectrum """
    dk,dl = k[1]-k[0],l[1]-l[0]
    l,k = np.meshgrid(l,k)
    wv = np.sqrt(k**2 + l**2)
    if k.max()>l.max():
        kmax = l.max()
    else:
        kmax = k.max()
    # create radial wavenumber

    dkr = np.sqrt(dk**2 + dl**2)

    kr =  np.arange(dkr/2.,kmax+dkr,dkr) #you should ask Hector about this line 

    ispec = np.zeros(kr.size)
    #print(ispec.shape)

    #print(kr.shape)
    for i in range(kr.size):
        fkr =  (wv>=kr[i]-dkr/2) & (wv<=kr[i]+dkr/2)
    #    print(fkr.shape)
        dth = math.pi / (fkr.sum()-1)
        ispec[i] = E[fkr].sum() * kr[i] * dth

    return kr, ispec

# %%
k = Q30txy[0,:,:].freq_lat.values
l = Q30txy[0,:,:].freq_lon.values
E = Q30txy[0,:,:].values

# %%
len(l)
# Out:
# 375

# %%
ndim = 'freq_time'
Q30txy.get_index(ndim)

# %%
kr, ispec = calc_ispec(k,l,Q30txy[0,:,:].values)

# %%
ispec

# %%
len(kr)

# %%
len(Q30txy['freq_time'].values)

# %% [markdown]
# I want to make a convenient function for handling the xarrays I feed to Hector's code

# %%
def isotropize(spectra, idims, ndim):
    # spectra should just be the xarray containing your fourier transformed data
    # idims should be a list of the dimensions you are reducing (i.e. kx, ky or k,l)
    # ndim is the dimension you use calc_ispec over - usually going to be time
    # I don't know how to support more than one ndim at the moment so I won't bother 
    # additionally, this assumes that the dim order is {ndim, kdstr, lstr}
    kstr = idims[0]
    lstr = idims[1]
    k = spectra[kstr].values
    l = spectra[lstr].values
    t = spectra[ndim].values
    dk,dl = k[1]-k[0],l[1]-l[0]
    l,k = np.meshgrid(l,k)
    wv = np.sqrt(k**2 + l**2)
    if k.max()>l.max():
        kmax = l.max()
    else:
        kmax = k.max()
    # create radial wavenumber
    dkr = np.sqrt(dk**2 + dl**2)
    kr =  np.arange(dkr/2.,kmax+dkr,dkr) #you should ask Hector about this line 
    ispec = np.empty([t.size, kr.size])
    for index in range(0,len(t)):
        E = spectra[index,:,:].values
        #print(kr.shape)
        for i in range(kr.size):
            fkr =  (wv>=kr[i]-dkr/2) & (wv<=kr[i]+dkr/2)
            #    print(fkr.shape)
            dth = math.pi / (fkr.sum()-1)
            check = (E[fkr].sum() * kr[i] * dth)
            #print(len(check))
            ispec[index, i] = check
    isospectra = xr.DataArray(data=ispec, dims = [ndim, 'kr'], coords = [t, kr], name='Isotropic Spectra')
    #now you need to put it back together in a convenient xarray type form
    return isospectra

# %%
from spectral_analysis_code import *
Q29txyiso = isotropize(Q29txy, ['freq_lat', 'freq_lon'], 'freq_time')

# %%
# %matplotlib inline
Q29txyiso.plot()

# %%
logQ29spectra = np.log(Q29txyiso)
logQ29spectra.rename('Log Isotropic Spectra')
# Out:
# <xarray.DataArray 'Log Isotropic Spectra' (freq_time: 1105, kr: 135)>
# array([[ 0.33027516,         nan,  0.62938071, ...,         nan,
#         -0.75914656,         nan],
#        [        nan,  0.62294619,         nan, ...,         nan,
#                 nan, -0.01264199],
#        [        nan,  0.966255  ,         nan, ..., -0.33875935,
#                 nan,         nan],
#        ...,
#        [-3.63158703,         nan, -1.93865812, ..., -0.92039987,
#                 nan, -0.03311867],
#        [        nan,         nan, -2.16750382, ...,         nan,
#         -1.41219562,         nan],
#        [        nan, -1.82638602,         nan, ...,         nan,
#         -0.05486667,         nan]])
# Coordinates:
#   * freq_time  (freq_time) float64 0.0 0.0004529 0.0009058 ... 0.4991 0.4995 0.5
#   * kr         (kr) float64 0.04622 0.1387 0.2311 0.3235 ... 12.25 12.34 12.43

# %%
# %matplotlib inline
logQ29spectra.plot()

# %% [markdown]
# Conclusions pertaining to this notebook:
# 1. LEARN DASK
# 1.5 FINISH ISOTROPIZING CODE
# 2. So according to Andrea, we should integrate to just pblh and no more. But we will check it in atmosphere and ocean.
# 3. To evaluate, we look at vertical heat flux (<w'T'>)
#  - So calculate W' and T' over some chosen length scale and then average in space
#  - might be good to look at spectra of this
# 4. Look at less than 100km,  AWAY FROM COASTS to avoid effects of turbulence going much farther up than the pbl

# %% [markdown]
# 11/19 I'll figure out the fourier stuff later, let me just do the spatial averaging of this

# %%
Q29= W29prime*T29prime
Q29.sizes
# Out:
# Frozen({'time': 2208, 'lat': 300, 'lon': 625})

# %%
Q.Zlayers.size
# Out:
# 2

# %%
lengthscale = 12 # 12*0.04 = 0.48 degrees
latsize = int(Q.lat.size/12)
lonsize = int(Q.lon.size/15)
Qcg30 = xr.DataArray(data = np.empty([2208]), dims = 'time')
for i in range(0,latsize):
    for j in range(0,lonsize):
        Qcg30 += Q.isel(lat=slice(i*12,(i+1)*12), lon=slice(j*15,(j+1)*15), Zlayers=0).mean(dim=['lat','lon']) / ((latsize)*(lonsize))

# %%
Qcg = xr.concat([Qcg26, Qcg27], dim='Zlayers')

# %%
lengthscale = 12 # 12*0.04 = 0.48 degrees
latsize = int(Q.lat.size/12)
lonsize = int(Q.lon.size/15)
zsize = Q.Zlayers.size
Qcgk= xr.DataArray(data = np.empty([2208]), dims = 'time')
for k in range(0,zsize):
    for i in range(0,latsize):
        for j in range(0,lonsize):
            Qcgk+= Q.isel(lat=slice(i*12,(i+1)*12), lon=slice(j*15,(j+1)*15), Zlayers=k).mean(dim=['lat','lon']) / ((latsize)*(lonsize))
    Qcg = xr.concat([Qcg,Qcgk],dim='Zlayers')
